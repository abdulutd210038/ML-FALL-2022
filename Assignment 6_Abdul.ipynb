# %% [markdown]
# # ASSIGNMENT 6 (MACHINE LEARNING)

# %% [markdown]
# # Q1: PLOT 10 FIGURES OF CHOICE

# %% [markdown]
# # NOTE: I PLOTTED 12 FIGURES. AT FIRST I ANALYZED THE DATA AND TRIED TO MAP SEVERAL OUTCOMES, RELATIONS, AND INDIVIDUAL COLUMN ANALYSIS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dt = pd.read_csv('LandslidesGlobal(1).csv')

# %%
dt
# Out:
#         id        date time         country  \
# 0        1  01/02/2007  NaN  United Kingdom
# 1        2  01/03/2007  NaN            Peru
# 2        3  01/05/2007  NaN          Brazil
# 3        4  01/05/2007  NaN          Brazil
# 4        5  01/05/2007  NaN          Brazil
# ...    ...         ...  ...             ...
# 9559   765  08/30/2008  NaN           Nepal
# 9560  9682  08/30/2008  NaN           Nepal
# 9561  9683  07/03/2011  NaN           Nepal
# 9562  9684  07/03/2011  NaN           Nepal
# 9563  9685  07/03/2011  NaN           Nepal
#
#                               nearest_places hazard_type landslide_type  \
# 0                        Whitehaven, Cumbria   landslide      Landslide
# 1       Alto Mesapata, in the Pasco province   landslide        Complex
# 2              Nova Friburgo, Rio de Janeiro   landslide      Landslide
# 3                  Sumidouro, Rio de Janeiro   landslide      Landslide
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9564 non-null   int64
#  1   date                  9563 non-null   object
#  2   time                  4024 non-null   object
#  3   country               6167 non-null   object
#  4   nearest_places        9472 non-null   object
#  5   hazard_type           9555 non-null   object
#  6   landslide_type        9546 non-null   object
#  7   trigger               8808 non-null   object
#  8   storm_name            550 non-null    object
#  9   fatalities            8212 non-null   float64
#  10  injuries              3942 non-null   float64
#  11  source_name           5545 non-null   object
#  12  source_link           8233 non-null   object
#  13  location_description  4109 non-null   object
#  14  location_accuracy     9562 non-null   object
# ...

# %%
# Removing unnecessary data

dt1 = dt.drop(["country","photos_link", "adminname1", "adminname2", "tstamp", 
         "source_name", "source_link", "nearest_places", "key", 
         "version", "changeset_id", "cat_src", "cat_id", "location_description", 
        "countrycode", "storm_name", "geolocation"], axis = 1)
dt1
# Out:
#         id        date time hazard_type landslide_type          trigger  \
# 0        1  01/02/2007  NaN   landslide      Landslide             Rain
# 1        2  01/03/2007  NaN   landslide        Complex             Rain
# 2        3  01/05/2007  NaN   landslide      Landslide             Rain
# 3        4  01/05/2007  NaN   landslide      Landslide             Rain
# 4        5  01/05/2007  NaN   landslide      Landslide             Rain
# ...    ...         ...  ...         ...            ...              ...
# 9559   765  08/30/2008  NaN   landslide      Landslide         Downpour
# 9560  9682  08/30/2008  NaN   landslide      Landslide         Downpour
# 9561  9683  07/03/2011  NaN   landslide      Landslide  Continuous_rain
# 9562  9684  07/03/2011  NaN   landslide      Landslide  Continuous_rain
# 9563  9685  07/03/2011  NaN   landslide      Landslide  Continuous_rain
#
#       fatalities  injuries   location_accuracy landslide_size     countryname  \
# ...

# %%
dt1['year']=pd.DatetimeIndex(dt1['date']).year
dt1
# Out:
#         id        date time hazard_type landslide_type          trigger  \
# 0        1  01/02/2007  NaN   landslide      Landslide             Rain
# 1        2  01/03/2007  NaN   landslide        Complex             Rain
# 2        3  01/05/2007  NaN   landslide      Landslide             Rain
# 3        4  01/05/2007  NaN   landslide      Landslide             Rain
# 4        5  01/05/2007  NaN   landslide      Landslide             Rain
# ...    ...         ...  ...         ...            ...              ...
# 9559   765  08/30/2008  NaN   landslide      Landslide         Downpour
# 9560  9682  08/30/2008  NaN   landslide      Landslide         Downpour
# 9561  9683  07/03/2011  NaN   landslide      Landslide  Continuous_rain
# 9562  9684  07/03/2011  NaN   landslide      Landslide  Continuous_rain
# 9563  9685  07/03/2011  NaN   landslide      Landslide  Continuous_rain
#
#       fatalities  injuries   location_accuracy landslide_size     countryname  \
# ...

# %% [markdown]
# FIGURE 1: THIS IS ABOUT LANDSLIDE SIZE COUNT TO FURTHER DWELL IN THE DATASET. WHOLE DATA IS RELATED TO EFFECTS CAUSED BY LANDSLIDES AND HAZARDS. SO FOR A GEENRAL IDEA, I PLOTTED THIS IN FIRST PLACE. IT TELLS ME THAT MEDIUM TYPE OF LANSLIDE SIZE OCCURED THE MOST.

# %%
import seaborn as sns
sns.set(style="darkgrid")
plt.subplots(figsize=(15,10))
sns.histplot(data=dt1, x="landslide_size")

plt.show()

# %% [markdown]
# FIGURE 2: THIS IS A HEATMAP PLOT WHICH IS TELLING OVERALL CORRELATION BETWEEN THE FEATURES OF THE DATA. HERE I FOUND THAT POPULATION IS AN IMPORTANT PARAMETER IN THIS DATASET.

# %%
plt.figure(figsize=(15,10), dpi= 80)
sns.heatmap(dt1.corr(), xticklabels=dt1.corr().columns, yticklabels=dt1.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram of data', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels
label_encoder = preprocessing.LabelEncoder()
  
dt1['country_name']= label_encoder.fit_transform(dt1['countryname'])
dt1['landslide_size1']= label_encoder.fit_transform(dt1['landslide_size'])
dt1['trigger_label']= label_encoder.fit_transform(dt1['trigger'])
dt1['hazard_type_label']= label_encoder.fit_transform(dt1['hazard_type'])

# %% [markdown]
# FIGURE 3: IT IS VERY INTERESTING PLOT BETWEEN THE DISTRIBUTION OF DIFFERENT LANDSLIDE SIZES BASED ON THEIR LATITUDES AND LONGITUDES AND WITH RESPECT TO THE YEAR IN WHICH THEY OCCUR.

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")


cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=dt1,
    x="longitude", y="latitude",
    hue="year", size="landslide_size1",
    palette=cmap, sizes=(100, 200), height = 10, aspect = 1.2,  
)
g.set(xscale="linear", yscale="linear")
g.ax.xaxis.grid(True, "minor", linewidth=1.25)
g.ax.yaxis.grid(True, "minor", linewidth=1.25)
g.despine(left=True, bottom=True)

# %% [markdown]
# FIGURE 4: SCATTER PLOT THAT TELLS US THE RELATIONSHIP BETWEEN POPULATION AND DISTANCE. WE CAN CLEARLY SEE THAT AS THE DISTANCE INCREASES, POPULATION DECREASES.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")


# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="distance", y="population",
                palette="ch:r=-.2,d=.3_r",
                sizes=(1, 8), linewidth=0,
                data=dt1, ax=ax)
# Out:
# <AxesSubplot:xlabel='distance', ylabel='population'>

# %%
pip install gapminder
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# FIGURE 5: THIS IS A BOXPLOT BETWEEN YEAR AND TRIGGERS. WE CAN SEE THAT RAIN WAS THE MOST COMMON TRIGGERING EFFECT FROM YEAR 2007 TO 2017

# %%
# import library & dataset
import seaborn as sns
  
plt.subplots(figsize=(15,10))
  
# Just switch x and y
sns.boxplot(y=dt1["trigger"], x=dt1["year"])
figsize=(100,100)

# %% [markdown]
# FIGURE 6: IT IS A 3D PLOT. TELLING US POPULATION WITH RESPECT TO LATITUDE AND LONGITUDE.

# %%
from mpl_toolkits import mplot3d


fig = plt.figure(figsize=(15,15))

ax = plt.axes(projection='3d')
ax.scatter3D(dt1["longitude"], dt1["latitude"], dt1["population"], alpha=.4, color = 'red')

#for changing the view
ax.view_init(20,20)

# %%
dt1
# Out:
#         id        date time hazard_type landslide_type          trigger  \
# 0        1  01/02/2007  NaN   landslide      Landslide             Rain
# 1        2  01/03/2007  NaN   landslide        Complex             Rain
# 2        3  01/05/2007  NaN   landslide      Landslide             Rain
# 3        4  01/05/2007  NaN   landslide      Landslide             Rain
# 4        5  01/05/2007  NaN   landslide      Landslide             Rain
# ...    ...         ...  ...         ...            ...              ...
# 9559   765  08/30/2008  NaN   landslide      Landslide         Downpour
# 9560  9682  08/30/2008  NaN   landslide      Landslide         Downpour
# 9561  9683  07/03/2011  NaN   landslide      Landslide  Continuous_rain
# 9562  9684  07/03/2011  NaN   landslide      Landslide  Continuous_rain
# 9563  9685  07/03/2011  NaN   landslide      Landslide  Continuous_rain
#
#       fatalities  injuries   location_accuracy landslide_size  ...  distance  \
# ...

# %%
dt1['countryname'].value_counts()
# Out:
# United States            3021
# India                    1273
# Philippines               676
# Nepal                     483
# China                     426
#                          ...
# Jordan                      1
# United Arab Emirates        1
# Republic of the Congo       1
# Slovenia                    1
# Cambodia                    1
# Name: countryname, Length: 141, dtype: int64

# %%
dt2 = dt1[['population', 'countryname', 'landslide_size1', 'year', 'fatalities']].copy()
dt2
# Out:
#       population     countryname  landslide_size1    year  fatalities
# 0        24803.0  United Kingdom                1  2007.0         1.0
# 1            0.0            Peru                1  2007.0         NaN
# 2       153361.0          Brazil                0  2007.0         7.0
# 3        11555.0          Brazil                1  2007.0         2.0
# 4        54415.0          Brazil                1  2007.0         1.0
# ...          ...             ...              ...     ...         ...
# 9559    107157.0           Nepal                1  2008.0         2.0
# 9560    107157.0           Nepal                1  2008.0         3.0
# 9561      3250.0           Nepal                1  2011.0         0.0
# 9562      3250.0           Nepal                1  2011.0         NaN
# 9563      3250.0           Nepal                1  2011.0         NaN
#
# [9564 rows x 5 columns]

# %% [markdown]
# FIG 7: IT IS A PAIRPLOT. I BELIEVE IT AS THE BEST PLOT OF THIS DATASET. WITH THIS PLOT, ONE CAN CLEARLY INTERPRET THE WHOLE DATASET. IT IS DESCRIBING ALL THE COUNTRIES AND RELATIONSHIPS BETWEEN POPULATION, INJURIES, FATALITIES AND OTHER PARAMETERS

# %%
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
sns.pairplot(dt2, hue='countryname')

# %% [markdown]
# FIGURE 8: THIS IS A PLOT BETWEEN TRIGGER AND HAZARD TYPE. I PLOTTED THIS TO GET A RELATIONSHIP THAT HOW DIFFERENT TRIGGER PARAMETERS CHANGES THE HAZARD TYPE.

# %%
x = dt1['trigger_label']
y = dt1['hazard_type_label']
import matplotlib.pyplot as plt

#create basic scatterplot
plt.plot(x, y, 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# %% [markdown]
# FIGURE 9: THIS IS IN CONTINUATION WITH THE PREVIOUS GRAPH. IT IS A DENSITY PLOT. IT IS TELLING THAT TRIGGER LABEL 3 AND 4 OCCURED THE MOST. SO IN OUR DATASET TRIGGER LABEL 3 IS CONTINUOS RAIN. SO, ONE CAN SAY THAT OVER THE NUMBER OF YEAR, IF YOU HAVE CONTINUOUS RAIN THEN YOU WOULD HAVE A SEVERE HAZARD TYPE.

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")
 
# Make default density plot
sns.kdeplot(dt1['trigger_label'])
plt.show()

# %% [markdown]
# FIGURE 10: IT IS VERY INTERESTING PLOT. IT IS BETWEEN INJURIES AND FATALITIES OCCURED OVER THE YEARS. WHILE RED DOTS IN DIFFERENT SIZED ARE PLOTTED BY TAKING "POPULATION" PARAMETER AS A SIZE. SO WE CAN FROM THIS PLOT EASILY INTERPRET THAT MAJORITY OF THE POPULATION DID NOT GET ANY SEVERE INJURIES AND FATALITIES. BUT, A SMALLER PORTION OF POPULATION ALSO GOT SOME DAMAGE (RED DOTS IN MIDDLE)

# %%
# libraries
import matplotlib.pyplot as plt
import seaborn as sns
from gapminder import gapminder # import data set 

# Control figure size for this notebook:
plt.rcParams['figure.figsize'] = [9, 9]


 
# use the scatterplot function to build the bubble map
sns.scatterplot(data=dt1, x="injuries", y="fatalities", size="population", legend=False, sizes=(20, 2000), color='red')

# show the graph
plt.show()

# %% [markdown]
# FIGURE 11: THIS IS A PLOT I PLOTTED INITIALLY TO HAVE AN IDEA THAT ARE DISTANCE AND HAZARD TYPE SHARE SOME RELATIONSHIP OR NOT. SO I FOUND THAT ALTHOUGH THEY DID NOT HAVE STRONG RELATIONSHIP, BUT WE CAN SEE THAT HAZARD TYPE 1 IS OCCURING ACROSS ALL THE DISTANCES.

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")


g = sns.jointplot(x="distance", y="hazard_type_label", data=dt1,
                  kind="reg", truncate=False,
                  xlim=(0, 60), ylim=(0, 12),
                  color="m", height=7)

# %%
values = ['United States']
dt3 = dt1[dt1. countryname.isin(values) == True]
dt3.head()
# Out:
#     id        date   time hazard_type landslide_type trigger  fatalities  \
# 23  24  02/11/2007    NaN   landslide      Landslide    Rain         NaN
# 26  27  02/15/2007    NaN   landslide      Landslide    Rain         NaN
# 29  30  02/27/2007    NaN   landslide        Complex    Rain         NaN
# 33  34  03/02/2007  night   landslide      Landslide    Rain         NaN
# 41  42  03/22/2007    NaN   landslide      Landslide    Rain         NaN
#
#     injuries  location_accuracy landslide_size  ... distance population  \
# 23       NaN  Known_within_5_km          Small  ...  9.96508     2933.0
# 26       NaN     Exact_Location         Medium  ...  0.67264     1465.0
# 29       NaN  Known_within_5_km         Medium  ...  4.28838   805235.0
# 33       NaN   Known_within_1km          Small  ...  3.40765    16000.0
# 41       NaN  Known_within_5_km          Small  ...  3.33522    17288.0
#
#     continentcode  latitude longitude    year  country_name  landslide_size1  \
# ...

# %% [markdown]
# FIGURE 12: THIS IS THE LAST PLOT I PLOTTED TO GET AN IDEA ABOUT THIS DATASET ESPECIALLY ACROSS THE UNITED STATES OF AMERICA. IT IS DESCRIBING THE RELATIONSHIP BETWEEN YEAR AND POPULATION OF UNITED STATES OF AMERICA.

# %%
# use the scatterplot function
sns.scatterplot(data=dt3, x="year", y="population", size="population", hue="countryname", alpha=0.5, sizes=(20, 400))

# show the graph
plt.show()

# %% [markdown]
# # Q2 PART (A) APPLY RANDOM FOREST AND GRADIENT BOOST ON YOU CLIMATE DATASET FROM PREVIOUS ASSIGNMENT

# %%
import time
start = time.time()

import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 1500)

import warnings
warnings.filterwarnings('ignore')

# -- Extend cell width

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Book6.csv')

# %%
data
# Out:
#             Date  N2O Monthly averaged  Temperature anomaly  \
# 0     1850-01-15                   NaN                  NaN
# 1     1850-02-15                   NaN                  NaN
# 2     1850-03-15                   NaN                  NaN
# 3     1850-04-15                   NaN                  NaN
# 4     1850-05-15                   NaN                  NaN
# ...          ...                   ...                  ...
# 2882     7/16/22                   NaN                  NaN
# 2883     8/15/22                   NaN                 0.94
# 2884     8/16/22                   NaN                  NaN
# 2885     9/15/22                   NaN                 0.88
# 2886     9/16/22                   NaN                  NaN
#
#       CH4 Monthly averaged  CO2 Monthly averaged
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# ...

# %%
df = data.copy()

# %%
conda install -c conda-forge missingno
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df2=df.dropna()
df2=df.dropna(axis=0)
df2.head()
# Out:
#          Date  N2O Monthly averaged  Temperature anomaly  \
# 2185  1/15/01                316.30                 0.45
# 2189  2/15/01                316.31                 0.44
# 2191  3/15/01                316.21                 0.55
# 2194  4/15/01                316.12                 0.50
# 2197  5/15/01                316.11                 0.57
#
#       CH4 Monthly averaged  CO2 Monthly averaged
# 2185               1772.86                370.69
# 2189               1772.48                371.18
# 2191               1773.64                371.59
# 2194               1773.84                371.90
# 2197               1770.71                371.80

# %%
df2.count()
# Out:
# Date                    258
# N2O Monthly averaged    258
# Temperature anomaly     258
# CH4 Monthly averaged    258
# CO2 Monthly averaged    258
# dtype: int64

# %%
df2['Date'] = pd.to_datetime(data['Date'])

# %%
df2
# Out:
#            Date  N2O Monthly averaged  Temperature anomaly  \
# 2185 2001-01-15                316.30                 0.45
# 2189 2001-02-15                316.31                 0.44
# 2191 2001-03-15                316.21                 0.55
# 2194 2001-04-15                316.12                 0.50
# 2197 2001-05-15                316.11                 0.57
# ...         ...                   ...                  ...
# 2871 2022-02-15                335.35                 0.89
# 2873 2022-03-15                335.40                 1.05
# 2875 2022-04-15                335.46                 0.83
# 2877 2022-05-15                335.48                 0.83
# 2879 2022-06-15                335.48                 0.92
#
#       CH4 Monthly averaged  CO2 Monthly averaged
# 2185               1772.86                370.69
# 2189               1772.48                371.18
# 2191               1773.64                371.59
# 2194               1773.84                371.90
# ...

# %%
df3 = df2.copy()

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()
  
df3['Temperature anomaly']= label_encoder.fit_transform(df3['Temperature anomaly'])
  
df3['Temperature anomaly'].unique()
# Out:
# array([ 5,  4, 14, 10, 16, 11, 18,  9, 31, 15, 36, 38, 47, 17, 23, 12, 20,
#        22, 13, 34,  8, 21,  2,  0, 19, 33, 26, 30, 32, 27,  7, 24, 28, 57,
#        29, 35,  1,  3,  6, 42, 51, 43, 40, 25, 37, 45, 41, 46, 39, 44, 49,
#        54, 60, 58, 63, 64, 67, 66, 61, 56, 50, 62, 53, 52, 48, 55, 59, 65])

# %%
df3
# Out:
#            Date  N2O Monthly averaged  Temperature anomaly  \
# 2185 2001-01-15                316.30                    5
# 2189 2001-02-15                316.31                    4
# 2191 2001-03-15                316.21                   14
# 2194 2001-04-15                316.12                   10
# 2197 2001-05-15                316.11                   16
# ...         ...                   ...                  ...
# 2871 2022-02-15                335.35                   48
# 2873 2022-03-15                335.40                   58
# 2875 2022-04-15                335.46                   42
# 2877 2022-05-15                335.48                   42
# 2879 2022-06-15                335.48                   51
#
#       CH4 Monthly averaged  CO2 Monthly averaged
# 2185               1772.86                370.69
# 2189               1772.48                371.18
# 2191               1773.64                371.59
# 2194               1773.84                371.90
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# -- heat map to see corrolation between features
corrmat = df3.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(30,30))

# -- plot heat map
sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn",)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from pandas.plotting import scatter_matrix
warnings.filterwarnings("ignore")

# %% [markdown]
# # APPLYING RANDOM FOREST

# %%
# %matplotlib inline
from pandas.plotting import scatter_matrix
features = ['CO2 Monthly averaged', 'CH4 Monthly averaged', 'N2O Monthly averaged']
X = df3.loc[:, features]
y = df3.loc[:, ['Temperature anomaly']]
attributes = df3.drop(columns='Temperature anomaly')
scatter_matrix(attributes, figsize=(30,30), alpha=0.8, marker='O')
# Out:
# array([[<AxesSubplot:xlabel='N2O Monthly averaged', ylabel='N2O Monthly averaged'>,
#         <AxesSubplot:xlabel='CH4 Monthly averaged', ylabel='N2O Monthly averaged'>,
#         <AxesSubplot:xlabel='CO2 Monthly averaged', ylabel='N2O Monthly averaged'>],
#        [<AxesSubplot:xlabel='N2O Monthly averaged', ylabel='CH4 Monthly averaged'>,
#         <AxesSubplot:xlabel='CH4 Monthly averaged', ylabel='CH4 Monthly averaged'>,
#         <AxesSubplot:xlabel='CO2 Monthly averaged', ylabel='CH4 Monthly averaged'>],
#        [<AxesSubplot:xlabel='N2O Monthly averaged', ylabel='CO2 Monthly averaged'>,
#         <AxesSubplot:xlabel='CH4 Monthly averaged', ylabel='CO2 Monthly averaged'>,
#         <AxesSubplot:xlabel='CO2 Monthly averaged', ylabel='CO2 Monthly averaged'>]],
#       dtype=object)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=0)
forest = RandomForestClassifier(n_estimators=100, random_state=0)
forest.fit(X_train, y_train)

print("Accuracy on training set: {:.3f}".format(forest.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(forest.score(X_test, y_test)))
# Out:
# Accuracy on training set: 1.000
# Accuracy on test set: 0.046

# %%
forest.feature_importances_
# Out:
# array([0.32967106, 0.33824215, 0.33208679])

# %%
# %matplotlib notebook

y_list = forest.feature_importances_
y_pos = np.arange(len(y_list))
features =['CO2 Monthly averaged', 'CH4 Monthly averaged', 'N2O Monthly averaged']
plt.barh(y_pos, y_list, align='center', alpha=0.4)
plt.yticks(y_pos, features)
# Out:
# <img src="data:image/png;base64,..." width="432">
# ([<matplotlib.axis.YTick at 0x7f8dd8a055e0>,
# ...
#  [Text(0, 0, 'CO2 Monthly averaged'),
#   Text(0, 1, 'CH4 Monthly averaged'),
#   Text(0, 2, 'N2O Monthly averaged')])

# %% [markdown]
# # APPLYING GRADIENT BOOST

# %%
from sklearn.ensemble import GradientBoostingClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

gbrt = GradientBoostingClassifier(random_state=0)
gbrt.fit(X_train, y_train)

print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(gbrt.score(X_test, y_test)))
# Out:
# Accuracy on training set: 1.000
# Accuracy on test set: 0.077

# %%
gbrt = GradientBoostingClassifier(random_state=0, max_depth=1)
gbrt.fit(X_train, y_train)

print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(gbrt.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.865
# Accuracy on test set: 0.062

# %%
gbrt = GradientBoostingClassifier(random_state=0, learning_rate=0.01)
gbrt.fit(X_train, y_train)

print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(gbrt.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.984
# Accuracy on test set: 0.062

# %%
# %matplotlib notebook

y_list = gbrt.feature_importances_
y_pos = np.arange(len(y_list))
features = ['CO2 Monthly averaged', 'CH4 Monthly averaged', 'N2O Monthly averaged']
plt.barh(y_pos, y_list, align='center', alpha=0.4)
plt.yticks(y_pos, features)
# Out:
# <img src="data:image/png;base64,..." width="432">
# ([<matplotlib.axis.YTick at 0x7f8df8d7e1c0>,
# ...
#  [Text(0, 0, 'CO2 Monthly averaged'),
#   Text(0, 1, 'CH4 Monthly averaged'),
#   Text(0, 2, 'N2O Monthly averaged')])

# %% [markdown]
# # Q2 PART (B) ENSEMBLE THE 4 MODELS FROM ASSIGNMENT 5
# NOTE: I HAVE 5 MODELS FROM ASSIGNMENT 5. I WILL IMPORT THOSE 5 MODELS HERE, AND WILL ENSEMBLE 4 OF THEM. ALTHOUGH THINGS ARE MAKING SENSE, BUT HAVE LOW SCORE. IT IS BECAUSE WE DID A LOT OF CLEANING IN THE ASSIGNMENT 5.

# %% [markdown]
# # KNN REGRESSOR

# %%
from sklearn.preprocessing import MinMaxScaler

drop_col_MinMax=[]
num_scalers = {}

for col in X:
    if pd.api.types.is_numeric_dtype(X[col].dtype): # just making sure all numberic are choosen, this line can be deleted
        print("MinMax scale of ", col)
        scaler = MinMaxScaler()
        scaler.fit(X[[col]])
        X[col+"_normalized"] = scaler.transform(X[[col]])
        drop_col_MinMax.append(col)

        
        
# -- view final file 
X = X.drop(columns=drop_col_MinMax)
X.head(3)
# Out:
# MinMax scale of  CO2 Monthly averaged
# MinMax scale of  CH4 Monthly averaged
# MinMax scale of  N2O Monthly averaged
#       CO2 Monthly averaged_normalized  CH4 Monthly averaged_normalized  \
# 2185                         0.047249                         0.068858
# 2189                         0.057018                         0.066277
# 2191                         0.065191                         0.074155
#
#       N2O Monthly averaged_normalized
# 2185                         0.009809
# 2189                         0.010325
# 2191                         0.005163

# %%
from sklearn.neighbors import KNeighborsRegressor

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0, test_size = 0.25)

# %%
# %matplotlib inline
train_score_array = []
test_score_array = []

for k in range(1,10):
    knn_reg = KNeighborsRegressor(k)
    knn_reg.fit(X_train, y_train)
    train_score_array.append(knn_reg.score(X_train, y_train))
    test_score_array.append(knn_reg.score(X_test, y_test))

x_axis = range(1,10)
plt.subplots(figsize = (20,5))
plt.plot(x_axis, train_score_array, c = 'g', label = 'Train Score')
plt.plot(x_axis, test_score_array, c = 'b', label = 'Test Score')
plt.legend()
plt.xlabel('n_neighbors')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
from sklearn.metrics import mean_squared_error

# -- fit algoritem to train data
knn_reg3 = KNeighborsRegressor(3)
knn_reg3.fit(X_train, y_train)

# -- predict target value for test dataset
y_predict_knn = knn_reg.predict(X_test)

# -- comapre target value of the model and abservation for both train and test dataset
print (knn_reg.score(X_train,y_train))
print (knn_reg.score(X_test,y_test))
# Out:
# 0.7256391758791789
# 0.6627973687874403

# %% [markdown]
# # DECISION TREE REGRESSOR

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
X_train_org, X_test_org, y_train, y_test = train_test_split(X,y, random_state = 0)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_org)
X_test = scaler.transform(X_test_org)

X_b = X_train[:50,2].reshape(-1,1)
y_b = y_train[:50]

clf = DecisionTreeRegressor()
clf.fit(X_b, y_b)

X_new=np.linspace(X_b.min(), X_b.max(), 50).reshape(50, 1)
y_predict = clf.predict(X_new)

plt.subplots(figsize = (20,5))
plt.plot(X_new, y_predict, c = 'royalblue')
plt.scatter(X_b, y_b)
plt.xlabel('N20 Monthly Averaged')
# Out:
# Text(0.5, 0, 'N20 Monthly Averaged')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

dtree = DecisionTreeRegressor(random_state=0)

dtree.fit(X_train, y_train)
print("Accuracy on training set: {:.3f}".format(dtree.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(dtree.score(X_test, y_test)))
# Out:
# Accuracy on training set: 1.000
# Accuracy on test set: 0.324

# %% [markdown]
# # LINEAR REGRESSION USING NORMAL EQUATION

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

X_train_org, X_test_org, y_train, y_test = train_test_split(X,y, random_state = 0)

scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train_org)
X_test = scaler.transform(X_test_org)

# %%
from sklearn.linear_model import LinearRegression

lreg = LinearRegression()
lreg.fit(X_train, y_train)
print(lreg.score(X_train, y_train))
print(lreg.score(X_test, y_test))
# Out:
# 0.5350401351147915
# 0.5792820731387927

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

X_train_rm = X_train[:,2].reshape(-1,1)
lreg.fit(X_train_rm, y_train)
y_predict = lreg.predict(X_train_rm)

plt.subplots(figsize = (20,5))
plt.plot(X_train_rm, y_predict, c = 'r')
plt.scatter(X_train_rm,y_train)
plt.xlabel('RM')
# Out:
# Text(0.5, 0, 'RM')

# %% [markdown]
# # SGD REGRESSOR

# %%
from sklearn.linear_model import SGDRegressor

sgd_reg = SGDRegressor(random_state= 0, max_iter = 100, learning_rate = 'constant', eta0 = 0.05, shuffle = False)
sgd_reg.fit(X_train, y_train)
print(sgd_reg.score(X_train, y_train))
print(sgd_reg.score(X_test, y_test))
# Out:
# 0.5325844619042596
# 0.5930466827758323

# %% [markdown]
# # POLYNOMIAL REGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

lreg = LinearRegression()
lreg.fit(X,y)

poly = PolynomialFeatures(degree = 2)
X_poly = poly.fit_transform(X)
poly_reg = LinearRegression()
poly_reg.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import pandas as pd



X_train_org, X_test_org, y_train, y_test = train_test_split(X,y, random_state = 0)

scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train_org)
X_test = scaler.transform(X_test_org)

# %%
from  sklearn.preprocessing  import PolynomialFeatures

poly = PolynomialFeatures(degree = 2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

poly_reg = LinearRegression()
poly_reg.fit(X_train_poly, y_train)

print(poly_reg.score(X_train_poly, y_train))
print(poly_reg.score(X_test_poly, y_test))
# Out:
# 0.5849128751176156
# 0.5849709452795179

# %% [markdown]
# # ENSEMBLING PART

# %%
#AVERAGE OF PREDICTED SCORED FOR THESE FIVE REGRESSOR MODELS
from statistics import mean 

inp_lst = [1, 0.55, 0.49, 0.70, 0.49] 
list_avg = mean(inp_lst)
print(list_avg)
# Out:
# 0.646

# %% [markdown]
# NOTE: WHEN I SIMPLY AVERAGED THE ABOVE SCORE, I WAS CONFUSED. SO I CONTACTED PROFESSOR MORTAZA, PROFESSOR TOLD ME THAT ENSEMBLING IS NOT JUST AVERAGING. SO, THEN I APPLIED THE FOLLOWING PART OF VOTING REGRESSOR AS A WAY TO ENSEMBLE MY REGRESSOR MODELS. AGAIN I WOULD SAY THAT, SCORES ARE NOT PERFECT, BECAUSE OF REMOVING AND CLEANING EXCESSIVE AMOUNT OF DATA IN THE ASSIGNMENT 5.

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import VotingRegressor

# %%
X, y = make_regression(n_samples=10000, n_features=3, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=43)

# %%
models = [('SGD', SGDRegressor()),
         ('Decision Tree', DecisionTreeRegressor()),
          ('LREG', LinearRegression()),
         ('KNN', KNeighborsRegressor())]
score = []
for name, model in models:
    model.fit(X_train, y_train)
    
    prediction = model.predict(X_test)
    score = mean_squared_error(y_test, prediction, squared = False)
    #scores = append.(score)
    print('{} Model RMSE: {}'.format(name,score))
# Out:
# SGD Model RMSE: 0.013201904605868807
# Decision Tree Model RMSE: 18.92781529569048
# LREG Model RMSE: 2.35562833712175e-13
# KNN Model RMSE: 9.792677204907434

# %%
ensemble = VotingRegressor(estimators=models)
ensemble.fit(X_train, y_train)
prediction = ensemble.predict(X_test)
score = mean_squared_error(y_test, prediction, squared = False)
print('Ensemble Model RMSE: {}'.format(score))
# Out:
# Ensemble Model RMSE: 5.838854892960632
